# %%
import pandas as pd

# %%
df=pd.read_csv("cars.csv",encoding="latin-1")

# %%
df
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
df.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
df.tail(1)
# Out:
#                dateCrawled                 name  seller offerType   price  \
# 49999  2016-03-14 00:42:12  Opel_Vectra_1.6_16V  privat   Angebot  $1,250
#
#         abtest vehicleType  yearOfRegistration  gearbox  powerPS   model  \
# 49999  control   limousine                1996  manuell      101  vectra
#
#         odometer  monthOfRegistration fuelType brand notRepairedDamage  \
# 49999  150,000km                    1   benzin  opel              nein
#
#                dateCreated  nrOfPictures  postalCode             lastSeen
# 49999  2016-03-13 00:00:00             0       45897  2016-04-06 21:18:48

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
df.shape
# Out:
# (50000, 20)

# %%
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   dateCrawled          50000 non-null  object
#  1   name                 50000 non-null  object
#  2   seller               50000 non-null  object
#  3   offerType            50000 non-null  object
#  4   price                50000 non-null  object
#  5   abtest               50000 non-null  object
#  6   vehicleType          44905 non-null  object
#  7   yearOfRegistration   50000 non-null  int64
#  8   gearbox              47320 non-null  object
#  9   powerPS              50000 non-null  int64
#  10  model                47242 non-null  object
#  11  odometer             50000 non-null  object
#  12  monthOfRegistration  50000 non-null  int64
#  13  fuelType             45518 non-null  object
#  14  brand                50000 non-null  object
# ...

# %%
df.describe()
# Out:
#        yearOfRegistration       powerPS  monthOfRegistration  nrOfPictures  \
# count        50000.000000  50000.000000         50000.000000       50000.0
# mean          2005.073280    116.355920             5.723360           0.0
# std            105.712813    209.216627             3.711984           0.0
# min           1000.000000      0.000000             0.000000           0.0
# 25%           1999.000000     70.000000             3.000000           0.0
# 50%           2003.000000    105.000000             6.000000           0.0
# 75%           2008.000000    150.000000             9.000000           0.0
# max           9999.000000  17700.000000            12.000000           0.0
#
#          postalCode
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %%
df.describe(include='object')
# Out:
#                 dateCrawled         name  seller offerType  price abtest  \
# count                 50000        50000   50000     50000  50000  50000
# unique                48213        38754       2         2   2357      2
# top     2016-04-02 11:37:04  Ford_Fiesta  privat   Angebot     $0   test
# freq                      3           78   49999     49999   1421  25756
#
#        vehicleType  gearbox  model   odometer fuelType       brand  \
# count        44905    47320  47242      50000    45518       50000
# unique           8        2    245         13        7          40
# top      limousine  manuell   golf  150,000km   benzin  volkswagen
# freq         12859    36993   4024      32424    30107       10687
#
#        notRepairedDamage          dateCreated             lastSeen
# count              40171                50000                50000
# unique                 2                   76                39481
# ...

# %%
for col in df.describe(include = 'object').columns:
    print(col)
# Out:
# dateCrawled
# name
# seller
# offerType
# price
# abtest
# vehicleType
# gearbox
# model
# odometer
# fuelType
# brand
# notRepairedDamage
# dateCreated
# lastSeen

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print("-"*50)
# Out:
# dateCrawled
# ['2016-03-26 17:47:46' '2016-04-04 13:38:56' '2016-03-26 18:57:24' ...
#  '2016-03-28 10:50:25' '2016-03-08 19:25:42' '2016-03-14 00:42:12']
# --------------------------------------------------
# name
# ['Peugeot_807_160_NAVTECH_ON_BOARD'
#  'BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik' 'Volkswagen_Golf_1.6_United'
#  ... 'Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon'
#  'Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+Reifen_neu_!!'
#  'Fiat_500_C_1.2_Dualogic_Lounge']
# --------------------------------------------------
# seller
# ['privat' 'gewerblich']
# --------------------------------------------------
# offerType
# ['Angebot' 'Gesuch']
# --------------------------------------------------
# price
# ['$5,000' '$8,500' '$8,990' ... '$385' '$22,200' '$16,995']
# --------------------------------------------------
# abtest
# ['control' 'test']
# --------------------------------------------------
# vehicleType
# ...

# %%
df['brand'].value_counts()
# Out:
# volkswagen        10687
# opel               5461
# bmw                5429
# mercedes_benz      4734
# audi               4283
# ford               3479
# renault            2404
# peugeot            1456
# fiat               1308
# seat                941
# skoda               786
# mazda               757
# nissan              754
# smart               701
# citroen             701
# toyota              617
# sonstige_autos      546
# hyundai             488
# volvo               457
# mini                424
# mitsubishi          406
# honda               399
# kia                 356
# alfa_romeo          329
# porsche             294
# suzuki              293
# chevrolet           283
# chrysler            181
# dacia               129
# daihatsu            128
# jeep                110
# subaru              109
# land_rover           99
# saab                 80
# daewoo               79
# trabant              78
# jaguar               77
# rover                69
# ...

# %%
df['brand'].value_counts(normalize= True)
# Out:
# volkswagen        0.21374
# opel              0.10922
# bmw               0.10858
# mercedes_benz     0.09468
# audi              0.08566
# ford              0.06958
# renault           0.04808
# peugeot           0.02912
# fiat              0.02616
# seat              0.01882
# skoda             0.01572
# mazda             0.01514
# nissan            0.01508
# smart             0.01402
# citroen           0.01402
# toyota            0.01234
# sonstige_autos    0.01092
# hyundai           0.00976
# volvo             0.00914
# mini              0.00848
# mitsubishi        0.00812
# honda             0.00798
# kia               0.00712
# alfa_romeo        0.00658
# porsche           0.00588
# suzuki            0.00586
# chevrolet         0.00566
# chrysler          0.00362
# dacia             0.00258
# daihatsu          0.00256
# jeep              0.00220
# subaru            0.00218
# land_rover        0.00198
# saab              0.00160
# daewoo            0.00158
# ...

# %%
selling_prop = df['brand'].value_counts(normalize= True)
selling_prop
# Out:
# volkswagen        0.21374
# opel              0.10922
# bmw               0.10858
# mercedes_benz     0.09468
# audi              0.08566
# ford              0.06958
# renault           0.04808
# peugeot           0.02912
# fiat              0.02616
# seat              0.01882
# skoda             0.01572
# mazda             0.01514
# nissan            0.01508
# smart             0.01402
# citroen           0.01402
# toyota            0.01234
# sonstige_autos    0.01092
# hyundai           0.00976
# volvo             0.00914
# mini              0.00848
# mitsubishi        0.00812
# honda             0.00798
# kia               0.00712
# alfa_romeo        0.00658
# porsche           0.00588
# suzuki            0.00586
# chevrolet         0.00566
# chrysler          0.00362
# dacia             0.00258
# daihatsu          0.00256
# jeep              0.00220
# subaru            0.00218
# land_rover        0.00198
# saab              0.00160
# daewoo            0.00158
# ...

# %%
selling_bool  = selling_prop > 0.05
selling_bool
# Out:
# volkswagen         True
# opel               True
# bmw                True
# mercedes_benz      True
# audi               True
# ford               True
# renault           False
# peugeot           False
# fiat              False
# seat              False
# skoda             False
# mazda             False
# nissan            False
# smart             False
# citroen           False
# toyota            False
# sonstige_autos    False
# hyundai           False
# volvo             False
# mini              False
# mitsubishi        False
# honda             False
# kia               False
# alfa_romeo        False
# porsche           False
# suzuki            False
# chevrolet         False
# chrysler          False
# dacia             False
# daihatsu          False
# jeep              False
# subaru            False
# land_rover        False
# saab              False
# daewoo            False
# trabant           False
# jaguar            False
# rover             False
# ...

# %%
selling_bool.shape
# Out:
# (40,)

# %%
selling_prop
# Out:
# volkswagen        0.21374
# opel              0.10922
# bmw               0.10858
# mercedes_benz     0.09468
# audi              0.08566
# ford              0.06958
# renault           0.04808
# peugeot           0.02912
# fiat              0.02616
# seat              0.01882
# skoda             0.01572
# mazda             0.01514
# nissan            0.01508
# smart             0.01402
# citroen           0.01402
# toyota            0.01234
# sonstige_autos    0.01092
# hyundai           0.00976
# volvo             0.00914
# mini              0.00848
# mitsubishi        0.00812
# honda             0.00798
# kia               0.00712
# alfa_romeo        0.00658
# porsche           0.00588
# suzuki            0.00586
# chevrolet         0.00566
# chrysler          0.00362
# dacia             0.00258
# daihatsu          0.00256
# jeep              0.00220
# subaru            0.00218
# land_rover        0.00198
# saab              0.00160
# daewoo            0.00158
# ...

# %%
top_brands = selling_prop[selling_bool]

# %%
top_brands
# Out:
# volkswagen       0.21374
# opel             0.10922
# bmw              0.10858
# mercedes_benz    0.09468
# audi             0.08566
# ford             0.06958
# Name: brand, dtype: float64

# %%
dir(top_brands)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
top_brands.values
# Out:
# array([0.21374, 0.10922, 0.10858, 0.09468, 0.08566, 0.06958])

# %%
top_brands.index
# Out:
# Index(['volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
brands_name = top_brands.index

# %%
brands_name
# Out:
# Index(['volkswagen', 'opel', 'bmw', 'mercedes_benz', 'audi', 'ford'], dtype='object')

# %%
df
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                    ...                                                ...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49997  2016-04-02 14:44:48                     Fiat_500_C_1.2_Dualogic_Lounge
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
brand_bol = df['brand'].isin(brands_name)

# %%
brand_bol
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 49995     True
# 49996     True
# 49997    False
# 49998     True
# 49999     True
# Name: brand, Length: 50000, dtype: bool

# %%
top_selling_brand = df[brand_bol].copy()

# %%
top_selling_brand.head(1)
# Out:
#            dateCrawled                                        name  seller  \
# 1  2016-04-04 13:38:56  BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik  privat
#
#   offerType   price   abtest vehicleType  yearOfRegistration    gearbox  \
# 1   Angebot  $8,500  control   limousine                1997  automatik
#
#    powerPS model   odometer  monthOfRegistration fuelType brand  \
# 1      286   7er  150,000km                    6   benzin   bmw
#
#   notRepairedDamage          dateCreated  nrOfPictures  postalCode  \
# 1              nein  2016-04-04 00:00:00             0       71034
#
#               lastSeen
# 1  2016-04-06 14:45:08

# %%
top_selling_brand['price']
# Out:
# 1         $8,500
# 2         $8,990
# 4         $1,350
# 6           $300
# 7         $1,990
#           ...
# 49994     $5,000
# 49995    $24,900
# 49996     $1,980
# 49998    $22,900
# 49999     $1,250
# Name: price, Length: 34073, dtype: object

# %%
top_selling_brand['price'] = top_selling_brand['price'].str.replace("$","").str.replace(",","").astype(int)
# Out:
# C:\Users\Atash\AppData\Local\Temp\ipykernel_1152\1148213236.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top_selling_brand['price'] = top_selling_brand['price'].str.replace("$","").str.replace(",","").astype(int)

# %%
top_selling_brand['price']
# Out:
# 1         8500
# 2         8990
# 4         1350
# 6          300
# 7         1990
#          ...
# 49994     5000
# 49995    24900
# 49996     1980
# 49998    22900
# 49999     1250
# Name: price, Length: 34073, dtype: int32

# %%
top_selling_brand['odometer'] = top_selling_brand['odometer'].str.replace("km","").str.replace(",","").astype(int)

# %%
top_selling_brand['odometer']
# Out:
# 1        150000
# 2         70000
# 4        150000
# 6        150000
# 7        150000
#           ...
# 49994    150000
# 49995    100000
# 49996    150000
# 49998     40000
# 49999    150000
# Name: odometer, Length: 34073, dtype: int32

# %%
 top_selling_brand=top_selling_brand.drop(["notRepairedDamage","nrOfPictures"],axis = 1)

# %%
top_selling_brand
# Out:
#                dateCrawled                                               name  \
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# ...                    ...                                                ...
# 49994  2016-03-22 17:36:42  Audi_A6__S6__Avant_4.2_quattro_eventuell_Tausc...
# 49995  2016-03-27 14:38:19   Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon
# 49996  2016-03-28 10:50:25  Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+...
# 49998  2016-03-08 19:25:42                 Audi_A3_2.0_TDI_Sportback_Ambition
# 49999  2016-03-14 00:42:12                                Opel_Vectra_1.6_16V
#
# ...

# %%
top_selling_brand.rename({"price":"price $","odometer":"odometer km"}, axis = 1, inplace = True)

# %%
top_selling_brand.head(4)
# Out:
#            dateCrawled                                               name  \
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 6  2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
#
#    seller offerType  price $   abtest vehicleType  yearOfRegistration  \
# 1  privat   Angebot     8500  control   limousine                1997
# 2  privat   Angebot     8990     test   limousine                2009
# 4  privat   Angebot     1350     test       kombi                2003
# 6  privat   Angebot      300     test   limousine                1995
#
#      gearbox  powerPS  model  odometer km  monthOfRegistration fuelType  \
# 1  automatik      286    7er       150000                    6   benzin
# 2    manuell      102   golf        70000                    7   benzin
# ...

# %%
groupping = top_selling_brand.groupby("brand")

# %%
groupping

# %%
brand_mean =groupping[["price $","odometer km"]].mean()

# %%
brand_mean
# Out:
#                     price $    odometer km
# brand
# audi            8965.560355  129643.941163
# bmw             8252.918954  132521.643028
# ford            7105.662547  124131.934464
# mercedes_benz  29511.955429  130886.142797
# opel            5106.092657  129298.663248
# volkswagen      6384.167400  128955.272761

# %%
sorted_brand_mean = brand_mean.sort_values("price $", ascending = False)

# %%
sorted_brand_mean
# Out:
#                     price $    odometer km
# brand
# mercedes_benz  29511.955429  130886.142797
# audi            8965.560355  129643.941163
# bmw             8252.918954  132521.643028
# ford            7105.662547  124131.934464
# volkswagen      6384.167400  128955.272761
# opel            5106.092657  129298.663248

# %%
sort_top_selling_brand = top_selling_brand["price $"].value_counts().sort_index()

# %%
top_selling_brand["yearOfRegistration"].value_counts().sort_index()
# Out:
# 1000    1
# 1910    2
# 1927    1
# 1929    1
# 1931    1
#        ..
# 5000    2
# 5911    1
# 6200    1
# 9000    1
# 9999    4
# Name: yearOfRegistration, Length: 79, dtype: int64

# %%
normal_price = top_selling_brand["price $"].between(1,3150000)

# %%
normal_price
# Out:
# 1        True
# 2        True
# 4        True
# 6        True
# 7        True
#          ...
# 49994    True
# 49995    True
# 49996    True
# 49998    True
# 49999    True
# Name: price $, Length: 34073, dtype: bool
